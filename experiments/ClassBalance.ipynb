# %%
import sys
sys.path.append('..')
import os
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')
import utils
from utils import *

# %%
train_dir='../cats/v1/train'
breeds = os.listdir(train_dir)

# %%
train_dir='../cats/v2/train'
breeds = os.listdir(train_dir)

# %%
train_dir='../cats/v3/train'
breeds = os.listdir(train_dir)

# %%
train_dir='../cats/v4/train'
breeds = os.listdir(train_dir)

# %%
train_dir='../cats/v4f/train'
breeds = os.listdir(train_dir)

# %%
train_dir='../cats/v6/train'
breeds = os.listdir(train_dir)

# %%
train_dir='../cats/v6f/train'
breeds = os.listdir(train_dir)

# %%
train_dir='../Flickr/flik'
breeds = os.listdir(train_dir)

# %%
breeds
len(breeds)
# Out:
# 10

# %%
def create_csv(filename, path):
    with open(filename, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['id','label'])
        for breed in os.listdir(path):
            files=os.listdir(path+'/'+breed)
            for file in files:
                writer.writerow([file, breed])

# %%
filename = 'catsv1.csv'
create_csv(filename, train_dir)

# %%
filename = 'catsv2.csv'
create_csv(filename, train_dir)

# %%
filename = 'catsv3.csv'# kaggle + iit
create_csv(filename, train_dir)

# %%
filename = 'catsv4.csv'# kaggle + iit + flickr egyptmau & snowshoe
create_csv(filename, train_dir)

# %%
filename = 'catsv4f.csv'# kaggle + iit + flickr all
create_csv(filename, train_dir)

# %%
filename = 'catsflik.csv'
create_csv(filename, train_dir)

# %%
filename = 'catsv6.csv' # kaggle + iit (british instead of birman)
create_csv(filename, train_dir)

# %%
filename = 'catsv6f.csv' # kaggle + iit (british instead of birman) + flickr all
create_csv(filename, train_dir)

# %%
df = pd.read_csv(filename)

# %%
def count_files(df, breed):
    a = df.apply(lambda x: True if x['label']==breed else False, axis=1)
    return len(a[a==True].index)

# %%
def plot_breed_frequency(df,title, max_x=5500):
    counts=[]
    plt.figure(figsize=(15,8))
    plt.xticks(np.arange(0,max_x,500))
    for breed in breeds:
        c = count_files(df, breed)
        counts.append(c)
    ss = sns.barplot(x=counts, y=breeds).set(title=title)

# %%
#catsv1
print(curTime().strftime("%D -- %H:%M"))
plot_breed_frequency(df, 'Kaggle')
# Out:
# Current Time = 21:46:11
# 04/08/21 -- 21:46

# %%
#catsv2
print(curTime().strftime("%D -- %H:%M"))
plot_breed_frequency(df, 'Kaggle + IIT')
# Out:
# Current Time = 13:21:07
# 04/09/21 -- 13:21

# %%
#catsv3 
print(curTime().strftime("%D -- %H:%M"))
plot_breed_frequency(df, 'Kaggle + IIT #10')
# Out:
# Current Time = 12:34:12
# 04/11/21 -- 12:34

# %%
#catsv4
print(curTime().strftime("%D -- %H:%M"))
plot_breed_frequency(df, 'Kaggle + IIT #10 +flik egyptian mau')
# Out:
# Current Time = 12:48:04
# 04/11/21 -- 12:48

# %%
#catsv4f
print(curTime().strftime("%D -- %H:%M"))
plot_breed_frequency(df, 'Kaggle + IIT #10 +flik', max_x=8000)
# Out:
# Current Time = 20:28:50
# 04/11/21 -- 20:28

# %%
#flickr
print(curTime().strftime("%D -- %H:%M"))
plot_breed_frequency(df, 'Flickr before pruning')
# Out:
# Current Time = 22:15:59
# 04/09/21 -- 22:15

# %%
#v6
print(curTime().strftime("%D -- %H:%M"))
plot_breed_frequency(df, 'Kaggle + IIT with B.Sh.') 
## add 2000 bsh
# Out:
# Current Time = 15:23:00
# 04/14/21 -- 15:23

# %%
#v6f
print(curTime().strftime("%D -- %H:%M"))
plot_breed_frequency(df, 'Kaggle + IIT with B.Sh. + flickr bsh')
# Out:
# Current Time = 15:42:33
# 04/14/21 -- 15:42

# %%
plot_breed_frequency(df)

# %%
df2 = pd.read_csv('data3.csv')

# %%
plot_breed_frequency(df2)

# %%
os.listdir('../data2/train')
# Out:
# ['Abyssinian',
#  'Bengal',
#  'Birman',
#  'Bombay',
#  'British Shorthair',
#  'Egyptian Mau',
#  'Maine Coon',
#  'Norwegian Forest Cat',
#  'Scottish Fold',
#  'Siamese',
#  'Snowshoe',
#  'Sphynx',
#  'Turkish Angora',
#  'Turkish Van',
#  'Tuxedo']

# %%
with open('data3.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['id','label'])
    for breed in os.listdir('../data2/train'):
        files=os.listdir('../data2/train/'+breed)
        for file in files:
            writer.writerow([file, breed])

# %%
df2
# Out:
#                                  id       label
# 0       1001061592_51b6908c3d_o.jpg  Abyssinian
# 1       1001061720_1ea84eb719_o.jpg  Abyssinian
# 2      10104031836_8cc66b6d65_k.jpg  Abyssinian
# 3       1016770207_19946da802_c.jpg  Abyssinian
# 4        103632492_c8bd24978c_o.jpg  Abyssinian
# ...                             ...         ...
# 32557               46803893_19.jpg      Tuxedo
# 32558               46803894_20.jpg      Tuxedo
# 32559               46804405_13.jpg      Tuxedo
# 32560                46806582_5.jpg      Tuxedo
# 32561                46806627_4.jpg      Tuxedo
#
# [32562 rows x 2 columns]
